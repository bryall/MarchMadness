# %% [markdown]
# # Data

# %%
import pandas as pd
from data import *
from data.filter import *
from data.clean import calc_two_point_shot_stats, merge_team_with_conference_with_season_results
from features.possession import *

# %%
df_tourney_all = get_tourney_compact_results_as_df()

df = get_regular_season_detailed_results_as_df()

df = limit_to_games_after_year(df, 2008)

df = merge_team_with_conference_with_season_results(df)

calc_two_point_shot_stats(df)

df.head()
# Out:
#    Season  DayNum  WTeamID  WScore  LTeamID  LScore WLoc  NumOT  WFGM  WFGA  \
# 0    2009       7     1181      80     1342      49    H      0    30    63
# 1    2009       8     1222      76     1342      57    N      0    30    56
# 2    2009      25     1155      79     1342      58    H      0    31    58
# 3    2009      18     1208      55     1342      47    H      0    25    52
# 4    2009      55     1266      84     1342      45    H      0    31    63
#
#    ...  LBlk  LPF  WTeamName                  WConfName     LTeamName  \
# 0  ...     5   25       Duke  Atlantic Coast Conference  Presbyterian
# 1  ...     3   18    Houston             Conference USA  Presbyterian
# 2  ...     0   17    Clemson  Atlantic Coast Conference  Presbyterian
# 3  ...     4   14    Georgia    Southeastern Conference  Presbyterian
# 4  ...     7   16  Marquette        Big East Conference  Presbyterian
#
#               LConfName  WFGM2  WFGA2  LFGM2  LFGA2
# ...

# %%
calc_posession(df)
df
# Out:
#        Season  DayNum  WTeamID  WScore  LTeamID  LScore WLoc  NumOT  WFGM  \
# 0        2009       7     1181      80     1342      49    H      0    30
# 1        2009       8     1222      76     1342      57    N      0    30
# 2        2009      25     1155      79     1342      58    H      0    31
# 3        2009      18     1208      55     1342      47    H      0    25
# 4        2009      55     1266      84     1342      45    H      0    31
# ...       ...     ...      ...     ...      ...     ...  ...    ...   ...
# 58674    2019      61     1316      96     1466      67    H      0    37
# 58675    2019      96     1316      82     1466      73    A      0    31
# 58676    2019     119     1316      76     1466      66    H      0    22
# 58677    2019      40     1422      53     1466      48    H      0    18
# 58678    2019      83     1312      76     1466      70    H      0    23
#
#        WFGA  ...       WTeamName                  WConfName      LTeamName  \
# ...

# %% [markdown]
# ## Basketball Stats as features
# Box-score data are used to calculate basketball statistics. These are the features to analyze and possibly model.

# %% [markdown]
# ### Regular Season Averages
